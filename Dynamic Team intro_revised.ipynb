# %%
print("""Hey! We are Team 11 and we are excited to introduce ourselves to you! 
\nLet's get started!\n""")
# prompt user to enter his/her name

user_name = input(prompt = 'Do let us know your name.  >> ')

# display team members' names and prompt the user to
# pick one team member to get to know them better
# user needs to enter the name of the member

print(f"""\nChoose a team member.\n 
1. J. Alberto Valencia Carrillo
2. Osaid Azeem
3. Sanskriti Garg
4. Thea Buzzi
5. Yunsik Choung
\nPick one to get to know them better!"""
)

# input from user about which team member he/she wants to know better
mem_sel = input(prompt = '\n >> ')

if '1' in mem_sel or mem_sel.lower() in 'j. alberto valencia carrillo' or mem_sel.lower() in 'j.albertovalenciacarrillo':
    mem_sel = 'J. Alberto Valencia Carrillo'

elif '2' in mem_sel or mem_sel.lower() in 'osaid azeem' or mem_sel.lower() in 'osaidazeem':
      mem_sel = 'Osaid Azeem'

elif '3' in mem_sel or mem_sel.lower() in 'sanskriti garg' or mem_sel.lower() in 'sanskritigarg':
      mem_sel = 'Sanskriti Garg'        

elif '4' in mem_sel or mem_sel.lower() in 'thea buzzi' or mem_sel.lower() in 'theabuzzi':
      mem_sel = 'Thea Buzzi'        

elif '5' in mem_sel or mem_sel.lower() in 'yunsik choung' or mem_sel.lower() in 'yunsikchoung':
      mem_sel = 'Yunsik Choung'

else:
     mem_sel = 'Invalid'


print(f"""\nSelect a nationality.\n 
1. Mexican
2. Pakistani
3. Indian
4. Swiss & Swedish
5. South Korean
""")

mem_nat = input(prompt = '\n >> ')

if '1' in mem_nat or mem_nat.lower() in 'mexican':
    mem_nat = 'a Mexican'

elif '2' in mem_nat or mem_nat.lower() in 'pakistani':
    mem_nat = 'a Pakistani'

elif '3' in mem_nat or mem_nat.lower() in 'indian':
    mem_nat = 'an Indian'
    
elif '4' in mem_nat or mem_nat.lower() in 'swiss & swedish':
    mem_nat = 'a Swiss & Swedish'

elif '5' in mem_nat or mem_nat.lower() in 'south korean':
    mem_nat = 'a South Korean'
    
else:
    mem_nat = 'Invalid'
    
print(f"""\nSelect a hobby.\n 
1. Hiking
2. Driving
3. Travelling
4. Painting 
5. Cooking
""")

mem_hob = input(prompt = '\n >> ')

if '1' in mem_hob or mem_hob.lower() in 'hiking':
    mem_hob = 'hiking'
    
elif '2' in mem_hob or mem_hob.lower() in 'driving':
    mem_hob = 'driving'

elif '3' in mem_hob or mem_hob.lower() in 'travelling' or mem_hob.lower() in 'traveling' :
    mem_hob = 'travelling'

elif '4' in mem_hob or mem_hob.lower() in 'painting':
    mem_hob = 'painting'

elif '5' in mem_hob or mem_hob.lower() in 'cooking':
    mem_hob = 'cooking'
    
else:
    mem_hob = "Invalid"
    
print(f"""\nSelect a job.\n 
1. Operation Analyst
2. Marketing Manager
3. Brand Manager
4. Business Support
5. Data Scientist
""")

mem_job = input(prompt = '\n >> ')

if '1' in mem_job or mem_job.lower() in 'operation analyst' or mem_job.lower() in 'operationanalyst' :
    mem_job = 'an Operation Analyst'
    
elif '2' in mem_job or mem_job.lower() in 'marketing manager' or mem_job.lower() in 'marketingmanager':
    mem_job = 'a Marketing Manager'    

elif '3' in mem_job or mem_job.lower() in 'brand manager' or mem_job.lower() in 'brandmanager':
    mem_job = 'a Brand Manager'    

elif '4' in mem_job or mem_job.lower() in 'business support' or mem_job.lower() in 'businesssupport':
    mem_job = 'a Business Support'    

elif '5' in mem_job or mem_job.lower() in 'data scientist' or mem_job.lower() in 'businesssupport':
    mem_job = 'a Data Scientist'    
    
else:
    mem_job = "Invalid"

print(f"""\nSelect a work field.\n 
1. Production
2. Education
3. Marketing
4. Finance
5. Start-up
""")

mem_field = input(prompt = '\n >> ')

if '1' in mem_field or mem_field.lower() in 'production':
    mem_field = 'Production'

elif '2' in mem_field or mem_field.lower() in 'education':
     mem_field = 'Education'

elif '3' in mem_field or mem_field.lower() in 'marketing':
    mem_field = 'Marketing'
    
elif '3' in mem_field or mem_field.lower() in 'finance':
    mem_field = 'Finance'

elif '3' in mem_field or mem_field.lower() in 'start-up' or mem_field.lower() in 'startup':
    mem_field = 'Start-up'

else: 
    mem_field = "Invalid"
    

print(f"""\nSelect a birthday.\n 
1. 21 April
2. 22 January
3. 29 July
4. 17 July
5. 12 September
""")

opt_1 = ['21', '21apr', '21 apr', '21stapr', '21st apr', '21 april', '21april','21stapril', '21st april', 'apr', 'april']
opt_2 = ['22', '22jan', '22 jan', '22ndjan', '22nd jan', '22 january', '21january','22ndjanuary', '22nd january', 'jan', 'january']
opt_3 = ['29', '29jul', '29 jul', '29july', '29 july', '29thjul', '29th jul', '29thjuly', '29th july'] 
opt_4 = ['17', '17july', '17 july', '17jul', '17 jul', '17thjul', '17th jul', '17thjuly', '17th july']
opt_5 = ['12', '12sep', '12 sep', '12 september','12september', '12sept', '12 sept', '12thsep', '12th sep', '12th september', '12thseptember']

mem_bday = input(prompt = '\n >> ')

if int(mem_bday) == 1 or mem_bday.lower() in opt_1:
    mem_bday = '21st April'
    
elif int(mem_bday) == 2 or mem_bday.lower() in opt_2:
    mem_bday = '22nd January'

elif int(mem_bday) == 3 or mem_bday.lower() in opt_3:
    mem_bday = '29th July'

elif int(mem_bday) == 4 or mem_bday.lower() in opt_4 :
    mem_bday = '17th July'

elif int(mem_bday) == 5 or mem_bday.lower() in opt_5:
    mem_bday = '12th September'
    
else:
    mem_bday = 'Invalid'
    
print(f"""\nSelect a education.\n 
1. BS
2. BBA
3. MBA
4. MPA
""")

mem_ed = input(prompt = '\n >> ')

if '1' in mem_ed or mem_ed.lower() in 'bs':
    mem_ed = 'BS'

elif '2' in mem_ed or mem_ed.lower() in 'bba':
    mem_ed = 'BBA'

elif '3' in mem_ed or mem_ed.lower() in 'mba':
    mem_ed = 'MBA'

elif '4' in mem_ed or mem_ed.lower() in 'mpa':
    mem_ed = 'MPA'

else: 
    mem_maj = "Invalid"


print(f"""\nSelect a major.\n 
1. International Business
2. Accounting
3. Marketing
4. Management
5. Public Statistics
""")

mem_maj = input(prompt = '\n >> ')

if '1' in mem_maj or mem_maj.lower() in 'international business' or mem_maj.lower() in 'internationalbusiness':
    mem_maj = 'International Business'

elif '2' in mem_maj or mem_maj.lower() in 'accounting':
    mem_maj = 'Accounting'
    
elif '3' in mem_maj or mem_maj.lower() in 'marketing':
    mem_field = 'Marketing'
    
elif '4' in mem_maj or mem_maj.lower() in 'management':
    mem_maj = 'Management'

elif '5' in mem_maj or mem_maj.lower() in 'public statistics' or mem_maj.lower() in 'publicstatistics':
    mem_maj = 'Public Statistics'

else: 
    mem_maj = "Invalid"


print(f"""\nSelect a graduate year.\n 
1. 2021
2. 2014
3. 2022
""")

mem_gradyr = input(prompt = '\n >> ')

if mem_gradyr =='1' or mem_gradyr =='2021' or mem_gradyr =='21':
    mem_gradyr = '2021'
    
elif mem_gradyr =='2' or mem_gradyr =='2014' or mem_gradyr =='14':
      mem_gradyr = '2014'

elif mem_gradyr =='3' or mem_gradyr =='2022' or mem_gradyr =='22':
      mem_gradyr = '2022'

else:
     mem_gradyr = 'Invalid'
    
print(f"""\nHey there! I am {mem_sel}. I am {mem_nat}. My birthday is on {mem_bday}.
I like {mem_hob}. I have work experience in {mem_field} and I last worked as {mem_job}. 
I have done my {mem_ed}.My major was {mem_maj}. I graduated in the year {mem_gradyr}. 
It was nice meeting you, {user_name}! Hope to see you around in class!""")
# Out:
# Hey! We are Team 11 and we are excited to introduce ourselves to you!
#
# Let's get started!
#
# Do let us know your name.  >> sansi
#
# Choose a team member.
#
# 1. J. Alberto Valencia Carrillo
# 2. Osaid Azeem
# 3. Sanskriti Garg
# 4. Thea Buzzi
# 5. Yunsik Choung
#
# Pick one to get to know them better!
#
#  >> 1
#
# Select a nationality.
#
# 1. Mexican
# 2. Pakistani
# 3. Indian
# 4. Swiss & Swedish
# 5. South Korean
#
#
#  >> indian
#
# Select a hobby.
#
# 1. Hiking
# 2. Driving
# 3. Travelling
# 4. Painting
# 5. Cooking
#
#
#  >> travelling
#
# Select a job.
#
# 1. Operation Analyst
# 2. Marketing Manager
# 3. Brand Manager
# 4. Business Support
# 5. Data Scientist
#
#
#  >> business
#
# Select a work field.
#
# 1. Production
# 2. Education
# 3. Marketing
# 4. Finance
# 5. Start-up
#
#
#  >> production
#
# Select a birthday.
#
# 1. 21 April
# 2. 22 January
# 3. 29 July
# 4. 17 July
# 5. 12 September
#
#
#  >> 21
#
# Select a education.
#
# 1. BS
# 2. BBA
# 3. MBA
# 4. MPA
#
#
# ...
